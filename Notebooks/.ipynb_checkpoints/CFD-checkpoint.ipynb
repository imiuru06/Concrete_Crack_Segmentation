# %% [markdown]
# ### dataset = Crack 500

# %% [markdown]
# ## Loading the important libraries and Dataset

# %%
! nvidia-smi
# Out:
# Sun Oct 11 12:12:11 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.100      Driver Version: 440.100      CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:01:00.0 Off |                  N/A |
# | 38%   55C    P0    92W / 250W |    259MiB / 11011MiB |     18%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  Off  | 00000000:03:00.0 Off |                  N/A |
# | 70%   75C    P2   244W / 250W |  10973MiB / 11019MiB |     95%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import os
import cv2
import shutil
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose, Add, concatenate, average, Dropout
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score, average_precision_score
#!pip install albumentations
from albumentations import Compose, OneOf, Flip, Rotate, RandomContrast, RandomGamma, RandomBrightness, ElasticTransform, GridDistortion, OpticalDistortion, RGBShift, CLAHE

# %%
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from skimage.transform import resize
from sklearn.metrics import classification_report

# %% [markdown]
# ### Loading the data and splitting it into training and validation set.

# %%
########################
# Path Set

# Dataset_dir
dataset_name = 'CFD'
dataset_dir = os.path.join('/data/crack', dataset_name)

#mode_name = ['train', 'val', 'test']

train_image_dir = os.path.join(dataset_dir,'train','image')
train_mask_dir = os.path.join(dataset_dir,'train','mask')


val_image_dir = os.path.join(dataset_dir,'val','image')
val_mask_dir = os.path.join(dataset_dir,'val','mask')

test_image_dir = os.path.join(dataset_dir,'test','image')
test_mask_dir = os.path.join(dataset_dir,'test','mask')

# model path

modelSave_name = "concrete_cracks_{}.h5".format(dataset_name)
model_path = os.path.join(dataset_dir, modelSave_name)

# %%
#########################
# USER Set

mode_run_type = ['train', 'inference']
mode_run = mode_run_type[0] # 0 is train, 1 is inference

set_valid = True # In train, if valid or not.
set_split_val = True
number_set_train = 84

os.environ["CUDA_VISIBLE_DEVICES"]='0'

# %%
train_image_paths = sorted([os.path.join(train_image_dir, fname) for fname in os.listdir(train_image_dir) if fname.endswith(".jpg") and not fname.startswith(".")])
train_mask_paths = sorted([os.path.join(train_mask_dir, fname) for fname in os.listdir(train_mask_dir) if fname.endswith(".png") and not fname.startswith(".")])
if set_valid:
    val_image_paths = sorted([os.path.join(val_image_dir, fname) for fname in os.listdir(val_image_dir) if fname.endswith(".jpg") and not fname.startswith(".")])
    val_mask_paths = sorted([os.path.join(val_mask_dir, fname) for fname in os.listdir(val_mask_dir) if fname.endswith(".png") and not fname.startswith(".")])

    test_image_paths = sorted([os.path.join(test_image_dir, fname) for fname in os.listdir(test_image_dir) if fname.endswith(".jpg") and not fname.startswith(".")])
    test_mask_paths = sorted([os.path.join(test_mask_dir, fname) for fname in os.listdir(test_mask_dir) if fname.endswith(".png") and not fname.startswith(".")])

print("Number of training images : ", len(train_image_paths))
print("Number of training masks : ", len(train_mask_paths))


print('\n')
if set_valid:
    print("Number of validating images : ", len(val_image_paths))
    print("Number of validating masks : ", len(val_mask_paths))
    print('\n')
    print("Number of testing images : ", len(test_image_paths))
    print("Number of testing masks : ", len(test_mask_paths))
# Out:
# Number of training images :  94
# Number of training masks :  94
#
#
# Number of validating images :  12
# Number of validating masks :  12
#
#
# Number of testing images :  24
# Number of testing masks :  24

# %%
# Shuffle
import random
combined = list(zip(train_image_paths, train_mask_paths))
random.shuffle(combined)
train_image_paths[:], train_mask_paths[:] = zip(*combined)

# %%
# Splitting
train_image_files = train_image_paths
train_mask_files = train_mask_paths

#valid_image_files = train_image_paths[150:]
#valid_mask_files = train_mask_paths[150:]
if set_valid:
    if set_split_val:
        
        train_image_files = train_image_paths[:number_set_train]
        train_mask_files = train_mask_paths[:number_set_train]                             
        val_image_files = train_image_paths[number_set_train:]
        val_mask_files = train_mask_paths[number_set_train:]
                                            
    else:
        val_image_files = val_image_paths
        val_mask_files = val_mask_paths                                    

print(len(train_image_files), len(train_mask_files))

if set_valid:
    print(len(val_image_files), len(val_mask_files))
# Out:
# 84 84
# 10 10

# %%
batch_size = 10
img_dim=(256, 256)

# %% [markdown]
# # Generator to load and augment the image batch wise

# %%
class Generator(Sequence):

  def __init__(self, x_set, y_set, batch_size=5, img_dim=(128, 128), augment=False):
      self.x = x_set
      self.y = y_set
      self.batch_size = batch_size
      self.img_dim = img_dim
      self.augment = augment

  def __len__(self):
      return math.ceil(len(self.x) / self.batch_size)

  augmentations = Compose(
    [                   
      Flip(p=0.7),
      Rotate(p=0.7),
      OneOf([
              RandomContrast(),
              RandomGamma(),
              RandomBrightness()
            ], p=0.3),
      OneOf([
              ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
              GridDistortion(),
              OpticalDistortion(distort_limit=2, shift_limit=0.5)
            ], p=0.3),
    ])

  def __getitem__(self, idx):
      batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
      batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

      batch_x = np.array([cv2.resize(cv2.cvtColor(cv2.imread(file_name, -1), cv2.COLOR_BGR2RGB), (self.img_dim[1], self.img_dim[0])) for file_name in batch_x])
      batch_y = np.array([(cv2.resize(cv2.imread(file_name, -1), (self.img_dim[1], self.img_dim[0]))>0).astype(np.uint8) for file_name in batch_y])

      if self.augment is True:
        aug = [self.augmentations(image=i, mask=j) for i, j in zip(batch_x, batch_y)]
        batch_x = np.array([i['image'] for i in aug])
        batch_y = np.array([j['mask'] for j in aug])

      batch_y = np.expand_dims(batch_y, -1)

      return batch_x/255, batch_y/1

# %%
test1_generator=Generator(test_image_paths,test_mask_paths)

# %%
# Validation generator samples (Un-augmented)
for i, j in test1_generator:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
train_generator = Generator(train_image_files, train_mask_files)
validation_generator = Generator(val_image_files, val_mask_files)

# %%
for i, j in train_generator:
  break

print(i.shape)
print(j.shape)
# Out:
# (5, 128, 128, 3)
# (5, 128, 128, 1)

# %%
for i, j in validation_generator:
  break

print(i.shape)
print(j.shape)
# Out:
# (5, 128, 128, 3)
# (5, 128, 128, 1)

# %%
# Train generator samples (Un-augmented)
for i, j in train_generator:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
# Validation generator samples (Un-augmented)
for i, j in validation_generator:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
tg = Generator(train_image_files, train_mask_files, batch_size, img_dim, augment = True)
vg = Generator(val_image_files, val_mask_files, batch_size, img_dim, augment = False)

# %%
for i, j in tg:
  break

print(i.shape)
print(j.shape)
# Out:
# (10, 256, 256, 3)
# (10, 256, 256, 1)

# %%
for i, j in vg:
  break

print(i.shape)
print(j.shape)
# Out:
# (10, 256, 256, 3)
# (10, 256, 256, 1)

# %%
# Augmented train
for i, j in tg:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Augmented Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Augmented Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model

# %%
import numpy as np
from tensorflow.keras.backend import int_shape
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Add, BatchNormalization, Input, Activation, Concatenate
from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
# BatchNormalization and Activation
def BN_Act(x, act = True):
    x = BatchNormalization()(x)
    if act == True:
        x = Activation("relu")(x)
    return x

# %%
#conv2d block
def conv2d_block(x, filters, kernel_size = (3, 3), padding = "same", strides = 1):
    conv = BN_Act(x)
    conv = Conv2D(filters, kernel_size, padding = padding, strides = strides)(conv)
    return conv

# %%
#Fixed layer.
def stem(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = Conv2D(filters, kernel_size, padding = padding, strides = strides)(x)
    conv = conv2d_block(conv, filters, kernel_size = kernel_size, padding = padding, strides = strides)
    
    #skip
    shortcut = Conv2D(filters, kernel_size = (1, 1), padding = padding, strides = strides)(x)
    shortcut = BN_Act(shortcut, act = False) # No activation in skip connection
    
    output = Add()([conv, shortcut])
    return output

# %%
# Residual Block
def residual_block(x, filters, kernel_size = (3, 3), padding = "same", strides = 1):
    res = conv2d_block(x, filters, kernel_size = kernel_size, padding = padding, strides = strides)
    res = conv2d_block(res, filters, kernel_size = kernel_size, padding = padding, strides = 1)
    
    shortcut = Conv2D(filters, kernel_size = (1, 1), padding = padding, strides = strides)(x)
    shortcut = BN_Act(shortcut, act = False) # No activation in skip connection
    
    output = Add()([shortcut, res])
    return output

# %%
# Upsampling Concatenation block
def upsample_concat_block(x, xskip):
    u = UpSampling2D((2, 2))(x)
    c = Concatenate()([u, xskip])
    return c

# %%
# MODEL
def ResUNet():
    f = [16, 32, 64, 128, 256]
    inputs = Input((img_dim[0], img_dim[1], 3))
    
    ## Encoder/downsampling/contracting path
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides = 2)
    e3 = residual_block(e2, f[2], strides = 2)
    e4 = residual_block(e3, f[3], strides = 2)
    e5 = residual_block(e4, f[4], strides = 2)
    
    ## Bridge/Bottleneck
    b0 = conv2d_block(e5, f[4], strides = 1)
    b1 = conv2d_block(b0, f[4], strides = 1)
    
    ## Decoder/upsampling/expansive path
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])
    
    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])
    
    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])
    
    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])
    
    outputs = Conv2D(1, (1, 1), padding = "same", activation = "sigmoid")(d4)
    model = Model(inputs, outputs)
    return model

# %%
K.clear_session()
model = ResUNet()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 16) 64          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 256, 16) 0           conv2d_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 16) 64          add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 4640        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 32) 544         add[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 32) 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 32) 0           batch_normalization_4[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 32) 128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   18496       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 64)   2112        add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64)   0           batch_normalization_7[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  8320        add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 128)  0           batch_normalization_10[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  295168      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 256)  33024       add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 256)  0           batch_normalization_13[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 256)  1024        add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 256)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 256)  590080      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 384)  0           up_sampling2d[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 384)  1536        concatenate[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 384)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 256)  884992      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 256)  98560       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 256)  590080      activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 256)  0           batch_normalization_18[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_1[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 320)  1280        concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 320)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 128)  368768      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 128)  41088       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 128)  0           batch_normalization_21[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           add_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 160 640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 160 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 64) 92224       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 64) 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 64) 10304       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 64) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 128, 128, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 128, 128, 64) 0           batch_normalization_24[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           add_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_3[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 256, 256, 80) 320         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 80) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 32) 23072       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256, 256, 32) 128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 256, 256, 32) 2592        concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 256, 256, 32) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 256, 256, 32) 128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 32) 9248        activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 256, 256, 32) 0           batch_normalization_27[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 256, 1)  33          add_8[0][0]
# ==================================================================================================
# Total params: 4,723,057
# Trainable params: 4,715,761
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import  plot_model

plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=100,
)

# %% [markdown]
# # Loss
# # &
# # Compile

# %%
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def IOU(y_true, y_pred):

    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)

    thresh = 0.5

    y_true = K.cast(K.greater_equal(y_true, thresh), 'float32')
    y_pred = K.cast(K.greater_equal(y_pred, thresh), 'float32')

    union = K.sum(K.maximum(y_true, y_pred)) + K.epsilon()
    intersection = K.sum(K.minimum(y_true, y_pred)) + K.epsilon()

    iou = intersection/union

    return iou

# %%
def lr_schedule(epoch):

    lr =0.001
    if epoch >150:
        lr *=2**-1
    elif epoch >80:
        lr *=2**(-1)
    elif epoch >50:
        lr *=2**(-1)
    elif epoch >30:
        lr *=2**(-1)
    
    print('Learning rate: ', lr)
    return lr

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD

# %%
import time

start_time = time.time()

# Prepare callbacks for model saving and for learning rate adjustment.
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-8)

callbacks = [lr_reducer, lr_scheduler]

# %%
import tensorflow as tf
learning_rate = 0.0035
optimiser=tf.keras.optimizers.Adam(
    learning_rate=lr_schedule(0),
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=True,
    name="Adam"
)

#from tensorflow.keras.utils import multi_gpu_model
#model = multi_gpu_model(model, gpus=4)

from tensorflow.python.client import device_lib
#from tensorflow.contrib.compiler import xla
device_lib.list_local_devices()


#from tensorflow.keras.utils import multi_gpu_model
#model = multi_gpu_model(model, gpus=4)

model.compile(optimizer =optimiser , loss = dice_coef_loss, metrics = ['accuracy', IOU, dice_coef])
# Out:
# Learning rate:  0.001

# %% [markdown]
# # Training

# %%
train_steps = len(train_image_files)//batch_size
valid_steps = len(val_image_files)//batch_size

history = model.fit(
    tg, 
    steps_per_epoch=train_steps,
    initial_epoch = 0,
    epochs=200,
    validation_data = vg,    
    validation_steps = valid_steps,callbacks=callbacks)
# Out:
# Learning rate:  0.001
# Epoch 1/200
# 7/8 [=========================>....] - ETA: 1s - loss: 0.9096 - acc: 0.7237 - IOU: 0.0548 - dice_coef: 0.0904Epoch 1/200
# 8/8 [==============================] - 12s 1s/step - loss: 0.8905 - acc: 0.7426 - IOU: 0.0674 - dice_coef: 0.1087 - val_loss: 0.9603 - val_acc: 0.0203 - val_IOU: 0.0203 - val_dice_coef: 0.0397
# Learning rate:  0.001
# Epoch 2/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7327 - acc: 0.9165 - IOU: 0.1740 - dice_coef: 0.2673Epoch 1/200
# 8/8 [==============================] - 1s 142ms/step - loss: 0.7339 - acc: 0.9215 - IOU: 0.1729 - dice_coef: 0.2665 - val_loss: 0.9579 - val_acc: 0.1167 - val_IOU: 0.0215 - val_dice_coef: 0.0421
# Learning rate:  0.001
# Epoch 3/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5700 - acc: 0.9743 - IOU: 0.2913 - dice_coef: 0.4300Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.5748 - acc: 0.9746 - IOU: 0.2865 - dice_coef: 0.4255 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 7.5309e-05
# Learning rate:  0.001
# Epoch 4/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5685 - acc: 0.9699 - IOU: 0.2909 - dice_coef: 0.4315Epoch 1/200
# 8/8 [==============================] - 1s 155ms/step - loss: 0.5797 - acc: 0.9705 - IOU: 0.2810 - dice_coef: 0.4203 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 8.2776e-05
# Learning rate:  0.001
# Epoch 5/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4952 - acc: 0.9744 - IOU: 0.3453 - dice_coef: 0.5048Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.4975 - acc: 0.9747 - IOU: 0.3434 - dice_coef: 0.5032 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 8.8967e-05
# Learning rate:  0.001
# Epoch 6/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4866 - acc: 0.9721 - IOU: 0.3518 - dice_coef: 0.5134Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.4906 - acc: 0.9720 - IOU: 0.3487 - dice_coef: 0.5105 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 1.1960e-04
# Learning rate:  0.001
# Epoch 7/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4443 - acc: 0.9773 - IOU: 0.3901 - dice_coef: 0.5557Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.4478 - acc: 0.9772 - IOU: 0.3871 - dice_coef: 0.5529 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 7.5353e-05
# Learning rate:  0.001
# Epoch 8/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4555 - acc: 0.9752 - IOU: 0.3808 - dice_coef: 0.5445Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.4505 - acc: 0.9758 - IOU: 0.3857 - dice_coef: 0.5501 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 7.5569e-05
# Learning rate:  0.001
# Epoch 9/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4326 - acc: 0.9769 - IOU: 0.4019 - dice_coef: 0.5674Epoch 1/200
# 8/8 [==============================] - 1s 142ms/step - loss: 0.4385 - acc: 0.9772 - IOU: 0.3965 - dice_coef: 0.5621 - val_loss: 0.9989 - val_acc: 0.9766 - val_IOU: 3.9037e-04 - val_dice_coef: 0.0011
# Learning rate:  0.001
# Epoch 10/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4189 - acc: 0.9777 - IOU: 0.4146 - dice_coef: 0.5811Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.4242 - acc: 0.9771 - IOU: 0.4095 - dice_coef: 0.5763 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 9.3572e-05
# Learning rate:  0.001
# Epoch 11/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4307 - acc: 0.9763 - IOU: 0.4045 - dice_coef: 0.5693Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.4314 - acc: 0.9768 - IOU: 0.4043 - dice_coef: 0.5696 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 8.2850e-05
# Learning rate:  0.001
# Epoch 12/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3909 - acc: 0.9808 - IOU: 0.4451 - dice_coef: 0.6091Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3841 - acc: 0.9808 - IOU: 0.4527 - dice_coef: 0.6167 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 9.4306e-05
# Learning rate:  0.001
# Epoch 13/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4013 - acc: 0.9793 - IOU: 0.4319 - dice_coef: 0.5987Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.4022 - acc: 0.9794 - IOU: 0.4308 - dice_coef: 0.5978 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 8.7952e-05
# Learning rate:  0.001
# Epoch 14/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4246 - acc: 0.9799 - IOU: 0.4066 - dice_coef: 0.5754Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.4368 - acc: 0.9780 - IOU: 0.3958 - dice_coef: 0.5640 - val_loss: 0.9999 - val_acc: 0.9797 - val_IOU: 7.5318e-12 - val_dice_coef: 8.8189e-05
# Learning rate:  0.001
# Epoch 15/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3757 - acc: 0.9823 - IOU: 0.4584 - dice_coef: 0.6243Epoch 1/200
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3702 - acc: 0.9825 - IOU: 0.4643 - dice_coef: 0.6303 - val_loss: 0.9933 - val_acc: 0.9798 - val_IOU: 0.0014 - val_dice_coef: 0.0067
# Learning rate:  0.001
# Epoch 16/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3940 - acc: 0.9799 - IOU: 0.4400 - dice_coef: 0.6060Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.4032 - acc: 0.9794 - IOU: 0.4305 - dice_coef: 0.5968 - val_loss: 0.9065 - val_acc: 0.9805 - val_IOU: 0.0537 - val_dice_coef: 0.0935
# Learning rate:  0.001
# Epoch 17/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3787 - acc: 0.9801 - IOU: 0.4568 - dice_coef: 0.6213Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3836 - acc: 0.9797 - IOU: 0.4516 - dice_coef: 0.6169 - val_loss: 0.9464 - val_acc: 0.9802 - val_IOU: 0.0262 - val_dice_coef: 0.0536
# Learning rate:  0.001
# Epoch 18/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3821 - acc: 0.9803 - IOU: 0.4528 - dice_coef: 0.6179Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3767 - acc: 0.9807 - IOU: 0.4586 - dice_coef: 0.6237 - val_loss: 0.9899 - val_acc: 0.9798 - val_IOU: 0.0044 - val_dice_coef: 0.0101
# Learning rate:  0.001
# Epoch 19/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3618 - acc: 0.9808 - IOU: 0.4733 - dice_coef: 0.6382Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3692 - acc: 0.9809 - IOU: 0.4657 - dice_coef: 0.6311 - val_loss: 0.9696 - val_acc: 0.9801 - val_IOU: 0.0159 - val_dice_coef: 0.0304
# Learning rate:  0.001
# Epoch 20/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3720 - acc: 0.9819 - IOU: 0.4627 - dice_coef: 0.6280Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3677 - acc: 0.9822 - IOU: 0.4668 - dice_coef: 0.6323 - val_loss: 0.9958 - val_acc: 0.9798 - val_IOU: 0.0020 - val_dice_coef: 0.0042
# Learning rate:  0.001
# Epoch 21/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3973 - acc: 0.9746 - IOU: 0.4386 - dice_coef: 0.6027Epoch 1/200
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3838 - acc: 0.9758 - IOU: 0.4547 - dice_coef: 0.6177 - val_loss: 0.9982 - val_acc: 0.9798 - val_IOU: 7.5318e-04 - val_dice_coef: 0.0018
# Learning rate:  0.001
# Epoch 22/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3554 - acc: 0.9825 - IOU: 0.4781 - dice_coef: 0.6446Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3549 - acc: 0.9830 - IOU: 0.4788 - dice_coef: 0.6452 - val_loss: 0.9679 - val_acc: 0.9801 - val_IOU: 0.0161 - val_dice_coef: 0.0321
# Learning rate:  0.001
# Epoch 23/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3606 - acc: 0.9814 - IOU: 0.4753 - dice_coef: 0.6394Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3526 - acc: 0.9815 - IOU: 0.4837 - dice_coef: 0.6474 - val_loss: 0.9645 - val_acc: 0.9801 - val_IOU: 0.0183 - val_dice_coef: 0.0355
# Learning rate:  0.001
# Epoch 24/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3645 - acc: 0.9806 - IOU: 0.4698 - dice_coef: 0.6355Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3564 - acc: 0.9812 - IOU: 0.4794 - dice_coef: 0.6442 - val_loss: 0.9779 - val_acc: 0.9800 - val_IOU: 0.0112 - val_dice_coef: 0.0221
# Learning rate:  0.001
# Epoch 25/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3760 - acc: 0.9789 - IOU: 0.4562 - dice_coef: 0.6240Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3717 - acc: 0.9796 - IOU: 0.4612 - dice_coef: 0.6287 - val_loss: 0.9540 - val_acc: 0.9802 - val_IOU: 0.0233 - val_dice_coef: 0.0460
# Learning rate:  0.001
# Epoch 26/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3538 - acc: 0.9820 - IOU: 0.4822 - dice_coef: 0.6462Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3530 - acc: 0.9821 - IOU: 0.4825 - dice_coef: 0.6469 - val_loss: 0.9609 - val_acc: 0.9801 - val_IOU: 0.0199 - val_dice_coef: 0.0391
# Learning rate:  0.001
# Epoch 27/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3610 - acc: 0.9811 - IOU: 0.4739 - dice_coef: 0.6390Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3690 - acc: 0.9808 - IOU: 0.4657 - dice_coef: 0.6314 - val_loss: 0.9604 - val_acc: 0.9801 - val_IOU: 0.0200 - val_dice_coef: 0.0396
# Learning rate:  0.001
# Epoch 28/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3573 - acc: 0.9809 - IOU: 0.4792 - dice_coef: 0.6427Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3629 - acc: 0.9810 - IOU: 0.4734 - dice_coef: 0.6377 - val_loss: 0.9741 - val_acc: 0.9800 - val_IOU: 0.0132 - val_dice_coef: 0.0259
# Learning rate:  0.001
# Epoch 29/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3645 - acc: 0.9807 - IOU: 0.4729 - dice_coef: 0.6355Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3555 - acc: 0.9809 - IOU: 0.4832 - dice_coef: 0.6453 - val_loss: 0.9544 - val_acc: 0.9802 - val_IOU: 0.0233 - val_dice_coef: 0.0456
# Learning rate:  0.001
# Epoch 30/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3573 - acc: 0.9792 - IOU: 0.4786 - dice_coef: 0.6427Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3622 - acc: 0.9797 - IOU: 0.4737 - dice_coef: 0.6385 - val_loss: 0.9658 - val_acc: 0.9801 - val_IOU: 0.0169 - val_dice_coef: 0.0342
# Learning rate:  0.001
# Epoch 31/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3306 - acc: 0.9846 - IOU: 0.5058 - dice_coef: 0.6694Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3478 - acc: 0.9827 - IOU: 0.4880 - dice_coef: 0.6522 - val_loss: 0.8030 - val_acc: 0.9818 - val_IOU: 0.1098 - val_dice_coef: 0.1970
# Learning rate:  0.0005
# Epoch 32/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3518 - acc: 0.9805 - IOU: 0.4831 - dice_coef: 0.6482Epoch 1/200
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3492 - acc: 0.9806 - IOU: 0.4865 - dice_coef: 0.6514 - val_loss: 0.7893 - val_acc: 0.9819 - val_IOU: 0.1182 - val_dice_coef: 0.2107
# Learning rate:  0.0005
# Epoch 33/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3263 - acc: 0.9828 - IOU: 0.5111 - dice_coef: 0.6737Epoch 1/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.3225 - acc: 0.9834 - IOU: 0.5154 - dice_coef: 0.6775 - val_loss: 0.7985 - val_acc: 0.9818 - val_IOU: 0.1125 - val_dice_coef: 0.2015
# Learning rate:  0.0005
# Epoch 34/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3375 - acc: 0.9817 - IOU: 0.5005 - dice_coef: 0.6625Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3310 - acc: 0.9827 - IOU: 0.5078 - dice_coef: 0.6692 - val_loss: 0.7506 - val_acc: 0.9825 - val_IOU: 0.1432 - val_dice_coef: 0.2494
# Learning rate:  0.0005
# Epoch 35/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3425 - acc: 0.9817 - IOU: 0.4944 - dice_coef: 0.6575Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3562 - acc: 0.9801 - IOU: 0.4804 - dice_coef: 0.6444 - val_loss: 0.7622 - val_acc: 0.9822 - val_IOU: 0.1353 - val_dice_coef: 0.2378
# Learning rate:  0.0005
# Epoch 36/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3117 - acc: 0.9842 - IOU: 0.5270 - dice_coef: 0.6883Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3157 - acc: 0.9842 - IOU: 0.5225 - dice_coef: 0.6844 - val_loss: 0.7703 - val_acc: 0.9822 - val_IOU: 0.1309 - val_dice_coef: 0.2297
# Learning rate:  0.0005
# Epoch 37/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3594 - acc: 0.9818 - IOU: 0.4749 - dice_coef: 0.6406Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3496 - acc: 0.9821 - IOU: 0.4867 - dice_coef: 0.6511 - val_loss: 0.6913 - val_acc: 0.9830 - val_IOU: 0.1817 - val_dice_coef: 0.3087
# Learning rate:  0.0005
# Epoch 38/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3017 - acc: 0.9853 - IOU: 0.5391 - dice_coef: 0.6983Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3115 - acc: 0.9847 - IOU: 0.5280 - dice_coef: 0.6886 - val_loss: 0.6389 - val_acc: 0.9838 - val_IOU: 0.2203 - val_dice_coef: 0.3611
# Learning rate:  0.0005
# Epoch 39/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3515 - acc: 0.9806 - IOU: 0.4851 - dice_coef: 0.6485Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3488 - acc: 0.9802 - IOU: 0.4884 - dice_coef: 0.6519 - val_loss: 0.5903 - val_acc: 0.9845 - val_IOU: 0.2575 - val_dice_coef: 0.4097
# Learning rate:  0.0005
# Epoch 40/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3236 - acc: 0.9820 - IOU: 0.5144 - dice_coef: 0.6764Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3285 - acc: 0.9821 - IOU: 0.5091 - dice_coef: 0.6718 - val_loss: 0.5611 - val_acc: 0.9850 - val_IOU: 0.2822 - val_dice_coef: 0.4389
# Learning rate:  0.0005
# Epoch 41/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3406 - acc: 0.9828 - IOU: 0.4960 - dice_coef: 0.6594Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3378 - acc: 0.9831 - IOU: 0.4991 - dice_coef: 0.6625 - val_loss: 0.5691 - val_acc: 0.9848 - val_IOU: 0.2744 - val_dice_coef: 0.4309
# Learning rate:  0.0005
# Epoch 42/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3324 - acc: 0.9812 - IOU: 0.5058 - dice_coef: 0.6676Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3273 - acc: 0.9818 - IOU: 0.5120 - dice_coef: 0.6732 - val_loss: 0.5646 - val_acc: 0.9849 - val_IOU: 0.2779 - val_dice_coef: 0.4354
# Learning rate:  0.0005
# Epoch 43/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3323 - acc: 0.9818 - IOU: 0.5063 - dice_coef: 0.6677Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3365 - acc: 0.9820 - IOU: 0.5011 - dice_coef: 0.6635 - val_loss: 0.5129 - val_acc: 0.9857 - val_IOU: 0.3204 - val_dice_coef: 0.4871
# Learning rate:  0.0005
# Epoch 44/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3259 - acc: 0.9828 - IOU: 0.5120 - dice_coef: 0.6741Epoch 1/200
# 8/8 [==============================] - 1s 142ms/step - loss: 0.3205 - acc: 0.9830 - IOU: 0.5193 - dice_coef: 0.6804 - val_loss: 0.5779 - val_acc: 0.9848 - val_IOU: 0.2673 - val_dice_coef: 0.4221
# Learning rate:  0.0005
# Epoch 45/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3364 - acc: 0.9823 - IOU: 0.5015 - dice_coef: 0.6636Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3384 - acc: 0.9824 - IOU: 0.4988 - dice_coef: 0.6616 - val_loss: 0.5278 - val_acc: 0.9855 - val_IOU: 0.3090 - val_dice_coef: 0.4722
# Learning rate:  0.0005
# Epoch 46/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3233 - acc: 0.9828 - IOU: 0.5151 - dice_coef: 0.6767Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3311 - acc: 0.9823 - IOU: 0.5067 - dice_coef: 0.6694 - val_loss: 0.5707 - val_acc: 0.9847 - val_IOU: 0.2742 - val_dice_coef: 0.4293
# Learning rate:  0.0005
# Epoch 47/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3311 - acc: 0.9825 - IOU: 0.5067 - dice_coef: 0.6689Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3272 - acc: 0.9833 - IOU: 0.5110 - dice_coef: 0.6731 - val_loss: 0.4986 - val_acc: 0.9859 - val_IOU: 0.3344 - val_dice_coef: 0.5014
# Learning rate:  0.0005
# Epoch 48/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3404 - acc: 0.9815 - IOU: 0.4943 - dice_coef: 0.6596Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3350 - acc: 0.9823 - IOU: 0.5005 - dice_coef: 0.6650 - val_loss: 0.4754 - val_acc: 0.9863 - val_IOU: 0.3570 - val_dice_coef: 0.5246
# Learning rate:  0.0005
# Epoch 49/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3039 - acc: 0.9836 - IOU: 0.5378 - dice_coef: 0.6961Epoch 1/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.3103 - acc: 0.9833 - IOU: 0.5306 - dice_coef: 0.6900 - val_loss: 0.4532 - val_acc: 0.9868 - val_IOU: 0.3785 - val_dice_coef: 0.5468
# Learning rate:  0.0005
# Epoch 50/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2875 - acc: 0.9858 - IOU: 0.5550 - dice_coef: 0.7125Epoch 1/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.2951 - acc: 0.9857 - IOU: 0.5467 - dice_coef: 0.7054 - val_loss: 0.4676 - val_acc: 0.9865 - val_IOU: 0.3626 - val_dice_coef: 0.5324
# Learning rate:  0.0005
# Epoch 51/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3349 - acc: 0.9821 - IOU: 0.5013 - dice_coef: 0.6651Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3338 - acc: 0.9824 - IOU: 0.5023 - dice_coef: 0.6662 - val_loss: 0.4526 - val_acc: 0.9867 - val_IOU: 0.3764 - val_dice_coef: 0.5474
# Learning rate:  0.0005
# Epoch 52/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3130 - acc: 0.9824 - IOU: 0.5266 - dice_coef: 0.6870Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3120 - acc: 0.9828 - IOU: 0.5280 - dice_coef: 0.6884 - val_loss: 0.4011 - val_acc: 0.9877 - val_IOU: 0.4286 - val_dice_coef: 0.5989
# Learning rate:  0.0005
# Epoch 53/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3327 - acc: 0.9827 - IOU: 0.5044 - dice_coef: 0.6673Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3304 - acc: 0.9833 - IOU: 0.5073 - dice_coef: 0.6702 - val_loss: 0.3479 - val_acc: 0.9887 - val_IOU: 0.4842 - val_dice_coef: 0.6521
# Learning rate:  0.0005
# Epoch 54/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3079 - acc: 0.9832 - IOU: 0.5331 - dice_coef: 0.6921Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3186 - acc: 0.9826 - IOU: 0.5216 - dice_coef: 0.6820 - val_loss: 0.3410 - val_acc: 0.9887 - val_IOU: 0.4915 - val_dice_coef: 0.6590
# Learning rate:  0.0005
# Epoch 55/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3423 - acc: 0.9819 - IOU: 0.4922 - dice_coef: 0.6577Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3307 - acc: 0.9823 - IOU: 0.5059 - dice_coef: 0.6693 - val_loss: 0.3578 - val_acc: 0.9887 - val_IOU: 0.4739 - val_dice_coef: 0.6422
# Learning rate:  0.0005
# Epoch 56/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3091 - acc: 0.9845 - IOU: 0.5301 - dice_coef: 0.6909Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3102 - acc: 0.9850 - IOU: 0.5292 - dice_coef: 0.6903 - val_loss: 0.2761 - val_acc: 0.9904 - val_IOU: 0.5690 - val_dice_coef: 0.7239
# Learning rate:  0.0005
# Epoch 57/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3613 - acc: 0.9788 - IOU: 0.4730 - dice_coef: 0.6387Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3523 - acc: 0.9800 - IOU: 0.4829 - dice_coef: 0.6477 - val_loss: 0.3143 - val_acc: 0.9890 - val_IOU: 0.5234 - val_dice_coef: 0.6857
# Learning rate:  0.0005
# Epoch 58/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3205 - acc: 0.9831 - IOU: 0.5184 - dice_coef: 0.6795Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3126 - acc: 0.9833 - IOU: 0.5275 - dice_coef: 0.6875 - val_loss: 0.2822 - val_acc: 0.9894 - val_IOU: 0.5610 - val_dice_coef: 0.7178
# Learning rate:  0.0005
# Epoch 59/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3033 - acc: 0.9851 - IOU: 0.5366 - dice_coef: 0.6967Epoch 1/200
# 8/8 [==============================] - 1s 149ms/step - loss: 0.2978 - acc: 0.9850 - IOU: 0.5435 - dice_coef: 0.7025 - val_loss: 0.3165 - val_acc: 0.9890 - val_IOU: 0.5196 - val_dice_coef: 0.6835
# Learning rate:  0.0005
# Epoch 60/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3382 - acc: 0.9815 - IOU: 0.4991 - dice_coef: 0.6618Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3367 - acc: 0.9820 - IOU: 0.5012 - dice_coef: 0.6641 - val_loss: 0.2829 - val_acc: 0.9899 - val_IOU: 0.5604 - val_dice_coef: 0.7171
# Learning rate:  0.0005
# Epoch 61/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3315 - acc: 0.9814 - IOU: 0.5063 - dice_coef: 0.6685Epoch 1/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.3282 - acc: 0.9819 - IOU: 0.5103 - dice_coef: 0.6723 - val_loss: 0.2813 - val_acc: 0.9901 - val_IOU: 0.5620 - val_dice_coef: 0.7187
# Learning rate:  0.0005
# Epoch 62/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3068 - acc: 0.9852 - IOU: 0.5322 - dice_coef: 0.6932Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3155 - acc: 0.9845 - IOU: 0.5227 - dice_coef: 0.6847 - val_loss: 0.3112 - val_acc: 0.9895 - val_IOU: 0.5265 - val_dice_coef: 0.6888
# Learning rate:  0.0005
# Epoch 63/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3139 - acc: 0.9836 - IOU: 0.5256 - dice_coef: 0.6861Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3203 - acc: 0.9835 - IOU: 0.5186 - dice_coef: 0.6802 - val_loss: 0.2897 - val_acc: 0.9897 - val_IOU: 0.5530 - val_dice_coef: 0.7103
# Learning rate:  0.0005
# Epoch 64/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3148 - acc: 0.9826 - IOU: 0.5246 - dice_coef: 0.6852Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3220 - acc: 0.9827 - IOU: 0.5165 - dice_coef: 0.6782 - val_loss: 0.3007 - val_acc: 0.9896 - val_IOU: 0.5383 - val_dice_coef: 0.6993
# Learning rate:  0.0005
# Epoch 65/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3277 - acc: 0.9829 - IOU: 0.5101 - dice_coef: 0.6723Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3200 - acc: 0.9831 - IOU: 0.5196 - dice_coef: 0.6806 - val_loss: 0.3065 - val_acc: 0.9898 - val_IOU: 0.5312 - val_dice_coef: 0.6935
# Learning rate:  0.0005
# Epoch 66/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3056 - acc: 0.9844 - IOU: 0.5349 - dice_coef: 0.6944Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3027 - acc: 0.9851 - IOU: 0.5386 - dice_coef: 0.6976 - val_loss: 0.2903 - val_acc: 0.9901 - val_IOU: 0.5507 - val_dice_coef: 0.7097
# Learning rate:  0.0005
# Epoch 67/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3173 - acc: 0.9826 - IOU: 0.5222 - dice_coef: 0.6827Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3162 - acc: 0.9829 - IOU: 0.5238 - dice_coef: 0.6843 - val_loss: 0.2522 - val_acc: 0.9907 - val_IOU: 0.5975 - val_dice_coef: 0.7478
# Learning rate:  0.0005
# Epoch 68/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3420 - acc: 0.9820 - IOU: 0.4931 - dice_coef: 0.6580Epoch 1/200
# 8/8 [==============================] - 1s 157ms/step - loss: 0.3352 - acc: 0.9821 - IOU: 0.5008 - dice_coef: 0.6648 - val_loss: 0.2708 - val_acc: 0.9904 - val_IOU: 0.5739 - val_dice_coef: 0.7292
# Learning rate:  0.0005
# Epoch 69/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3132 - acc: 0.9838 - IOU: 0.5267 - dice_coef: 0.6868Epoch 1/200
# 8/8 [==============================] - 1s 137ms/step - loss: 0.3258 - acc: 0.9830 - IOU: 0.5140 - dice_coef: 0.6755 - val_loss: 0.2287 - val_acc: 0.9913 - val_IOU: 0.6287 - val_dice_coef: 0.7713
# Learning rate:  0.0005
# Epoch 70/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3054 - acc: 0.9829 - IOU: 0.5351 - dice_coef: 0.6946Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3047 - acc: 0.9831 - IOU: 0.5357 - dice_coef: 0.6953 - val_loss: 0.2418 - val_acc: 0.9910 - val_IOU: 0.6127 - val_dice_coef: 0.7582
# Learning rate:  0.0005
# Epoch 71/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3358 - acc: 0.9835 - IOU: 0.5001 - dice_coef: 0.6642Epoch 1/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.3292 - acc: 0.9842 - IOU: 0.5075 - dice_coef: 0.6708 - val_loss: 0.2369 - val_acc: 0.9914 - val_IOU: 0.6180 - val_dice_coef: 0.7631
# Learning rate:  0.0005
# Epoch 72/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3217 - acc: 0.9821 - IOU: 0.5161 - dice_coef: 0.6783Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3175 - acc: 0.9825 - IOU: 0.5212 - dice_coef: 0.6828 - val_loss: 0.2436 - val_acc: 0.9910 - val_IOU: 0.6085 - val_dice_coef: 0.7564
# Learning rate:  0.0005
# Epoch 73/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3211 - acc: 0.9816 - IOU: 0.5169 - dice_coef: 0.6789Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3168 - acc: 0.9827 - IOU: 0.5223 - dice_coef: 0.6837 - val_loss: 0.2492 - val_acc: 0.9906 - val_IOU: 0.6018 - val_dice_coef: 0.7508
# Learning rate:  0.0005
# Epoch 74/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3452 - acc: 0.9826 - IOU: 0.4913 - dice_coef: 0.6548Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3432 - acc: 0.9830 - IOU: 0.4936 - dice_coef: 0.6573 - val_loss: 0.2490 - val_acc: 0.9894 - val_IOU: 0.6032 - val_dice_coef: 0.7510
# Learning rate:  0.0005
# Epoch 75/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3131 - acc: 0.9813 - IOU: 0.5262 - dice_coef: 0.6869Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3189 - acc: 0.9816 - IOU: 0.5198 - dice_coef: 0.6814 - val_loss: 0.2224 - val_acc: 0.9906 - val_IOU: 0.6368 - val_dice_coef: 0.7776
# Learning rate:  0.0005
# Epoch 76/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3373 - acc: 0.9814 - IOU: 0.4994 - dice_coef: 0.6627Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3373 - acc: 0.9819 - IOU: 0.4996 - dice_coef: 0.6632 - val_loss: 0.2170 - val_acc: 0.9914 - val_IOU: 0.6436 - val_dice_coef: 0.7830
# Learning rate:  0.0005
# Epoch 77/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2812 - acc: 0.9868 - IOU: 0.5625 - dice_coef: 0.7188Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.2831 - acc: 0.9868 - IOU: 0.5601 - dice_coef: 0.7169 - val_loss: 0.2187 - val_acc: 0.9915 - val_IOU: 0.6431 - val_dice_coef: 0.7813
# Learning rate:  0.0005
# Epoch 78/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3320 - acc: 0.9815 - IOU: 0.5074 - dice_coef: 0.6680Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3309 - acc: 0.9819 - IOU: 0.5085 - dice_coef: 0.6696 - val_loss: 0.2299 - val_acc: 0.9906 - val_IOU: 0.6269 - val_dice_coef: 0.7701
# Learning rate:  0.0005
# Epoch 79/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3186 - acc: 0.9825 - IOU: 0.5203 - dice_coef: 0.6814Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3246 - acc: 0.9827 - IOU: 0.5138 - dice_coef: 0.6758 - val_loss: 0.2896 - val_acc: 0.9879 - val_IOU: 0.5519 - val_dice_coef: 0.7104
# Learning rate:  0.0005
# Epoch 80/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3278 - acc: 0.9830 - IOU: 0.5097 - dice_coef: 0.6722Epoch 1/200
# 8/8 [==============================] - 1s 133ms/step - loss: 0.3249 - acc: 0.9831 - IOU: 0.5136 - dice_coef: 0.6760 - val_loss: 0.2352 - val_acc: 0.9900 - val_IOU: 0.6209 - val_dice_coef: 0.7648
# Learning rate:  0.0005
# Epoch 81/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3333 - acc: 0.9818 - IOU: 0.5034 - dice_coef: 0.6667Epoch 1/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.3314 - acc: 0.9822 - IOU: 0.5052 - dice_coef: 0.6686 - val_loss: 0.2220 - val_acc: 0.9910 - val_IOU: 0.6367 - val_dice_coef: 0.7780
# Learning rate:  0.0005
# Epoch 82/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3383 - acc: 0.9823 - IOU: 0.4961 - dice_coef: 0.6617Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3306 - acc: 0.9827 - IOU: 0.5052 - dice_coef: 0.6697 - val_loss: 0.2725 - val_acc: 0.9890 - val_IOU: 0.5729 - val_dice_coef: 0.7275
# Learning rate:  0.0005
# Epoch 83/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3253 - acc: 0.9817 - IOU: 0.5125 - dice_coef: 0.6747Epoch 1/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.3273 - acc: 0.9819 - IOU: 0.5102 - dice_coef: 0.6727 - val_loss: 0.2225 - val_acc: 0.9912 - val_IOU: 0.6364 - val_dice_coef: 0.7775
# Learning rate:  0.0005
# Epoch 84/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3067 - acc: 0.9817 - IOU: 0.5348 - dice_coef: 0.6933Epoch 1/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3159 - acc: 0.9816 - IOU: 0.5245 - dice_coef: 0.6844 - val_loss: 0.2123 - val_acc: 0.9917 - val_IOU: 0.6506 - val_dice_coef: 0.7877
# Learning rate:  0.0005
# Epoch 85/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3690 - acc: 0.9818 - IOU: 0.4662 - dice_coef: 0.6310Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3560 - acc: 0.9822 - IOU: 0.4819 - dice_coef: 0.6449 - val_loss: 0.3444 - val_acc: 0.9875 - val_IOU: 0.4885 - val_dice_coef: 0.6556
# Learning rate:  0.0005
# Epoch 86/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3449 - acc: 0.9817 - IOU: 0.4906 - dice_coef: 0.6551Epoch 1/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.3456 - acc: 0.9821 - IOU: 0.4896 - dice_coef: 0.6544 - val_loss: 0.3149 - val_acc: 0.9875 - val_IOU: 0.5211 - val_dice_coef: 0.6851
# Learning rate:  0.0005
# Epoch 87/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2942 - acc: 0.9860 - IOU: 0.5474 - dice_coef: 0.7058Epoch 1/200
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3046 - acc: 0.9851 - IOU: 0.5357 - dice_coef: 0.6955 - val_loss: 0.2108 - val_acc: 0.9911 - val_IOU: 0.6525 - val_dice_coef: 0.7892
# Learning rate:  0.0005
# Epoch 88/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3269 - acc: 0.9828 - IOU: 0.5115 - dice_coef: 0.6731Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3182 - acc: 0.9829 - IOU: 0.5214 - dice_coef: 0.6818 - val_loss: 0.2255 - val_acc: 0.9907 - val_IOU: 0.6333 - val_dice_coef: 0.7745
# Learning rate:  0.0005
# Epoch 89/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3417 - acc: 0.9816 - IOU: 0.4938 - dice_coef: 0.6583Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3388 - acc: 0.9820 - IOU: 0.4970 - dice_coef: 0.6615 - val_loss: 0.2239 - val_acc: 0.9911 - val_IOU: 0.6353 - val_dice_coef: 0.7761
# Learning rate:  0.0005
# Epoch 90/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3179 - acc: 0.9831 - IOU: 0.5215 - dice_coef: 0.6821Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3136 - acc: 0.9833 - IOU: 0.5266 - dice_coef: 0.6867 - val_loss: 0.2204 - val_acc: 0.9913 - val_IOU: 0.6398 - val_dice_coef: 0.7796
# Learning rate:  0.0005
# Epoch 91/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3123 - acc: 0.9843 - IOU: 0.5256 - dice_coef: 0.6877Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3157 - acc: 0.9845 - IOU: 0.5219 - dice_coef: 0.6845 - val_loss: 0.2211 - val_acc: 0.9911 - val_IOU: 0.6378 - val_dice_coef: 0.7789
# Learning rate:  0.0005
# Epoch 92/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3402 - acc: 0.9827 - IOU: 0.4959 - dice_coef: 0.6598Epoch 1/200
# 8/8 [==============================] - 1s 155ms/step - loss: 0.3488 - acc: 0.9813 - IOU: 0.4864 - dice_coef: 0.6512 - val_loss: 0.2169 - val_acc: 0.9913 - val_IOU: 0.6441 - val_dice_coef: 0.7831
# Learning rate:  0.0005
# Epoch 93/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3211 - acc: 0.9815 - IOU: 0.5164 - dice_coef: 0.6789Epoch 1/200
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3131 - acc: 0.9819 - IOU: 0.5265 - dice_coef: 0.6876 - val_loss: 0.2189 - val_acc: 0.9913 - val_IOU: 0.6420 - val_dice_coef: 0.7811
# Learning rate:  0.0005
# Epoch 94/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3047 - acc: 0.9856 - IOU: 0.5346 - dice_coef: 0.6953Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3212 - acc: 0.9835 - IOU: 0.5173 - dice_coef: 0.6792 - val_loss: 0.2091 - val_acc: 0.9917 - val_IOU: 0.6555 - val_dice_coef: 0.7909
# Learning rate:  0.0005
# Epoch 95/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2924 - acc: 0.9837 - IOU: 0.5510 - dice_coef: 0.7076Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2916 - acc: 0.9844 - IOU: 0.5520 - dice_coef: 0.7086 - val_loss: 0.2123 - val_acc: 0.9913 - val_IOU: 0.6510 - val_dice_coef: 0.7877
# Learning rate:  0.0005
# Epoch 96/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3171 - acc: 0.9840 - IOU: 0.5213 - dice_coef: 0.6829Epoch 1/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.3304 - acc: 0.9823 - IOU: 0.5068 - dice_coef: 0.6696 - val_loss: 0.2059 - val_acc: 0.9917 - val_IOU: 0.6593 - val_dice_coef: 0.7941
# Learning rate:  0.0005
# Epoch 97/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3014 - acc: 0.9856 - IOU: 0.5387 - dice_coef: 0.6986Epoch 1/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3033 - acc: 0.9855 - IOU: 0.5372 - dice_coef: 0.6974 - val_loss: 0.2121 - val_acc: 0.9914 - val_IOU: 0.6507 - val_dice_coef: 0.7879
# Learning rate:  0.0005
# Epoch 98/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3159 - acc: 0.9830 - IOU: 0.5237 - dice_coef: 0.6841Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3101 - acc: 0.9838 - IOU: 0.5302 - dice_coef: 0.6899 - val_loss: 0.2038 - val_acc: 0.9917 - val_IOU: 0.6632 - val_dice_coef: 0.7962
# Learning rate:  0.0005
# Epoch 99/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3142 - acc: 0.9825 - IOU: 0.5250 - dice_coef: 0.6858Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3116 - acc: 0.9821 - IOU: 0.5283 - dice_coef: 0.6888 - val_loss: 0.2106 - val_acc: 0.9912 - val_IOU: 0.6535 - val_dice_coef: 0.7894
# Learning rate:  0.0005
# Epoch 100/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3086 - acc: 0.9824 - IOU: 0.5318 - dice_coef: 0.6914Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3074 - acc: 0.9832 - IOU: 0.5332 - dice_coef: 0.6929 - val_loss: 0.2096 - val_acc: 0.9911 - val_IOU: 0.6544 - val_dice_coef: 0.7904
# Learning rate:  0.0005
# Epoch 101/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2989 - acc: 0.9858 - IOU: 0.5424 - dice_coef: 0.7011Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3019 - acc: 0.9858 - IOU: 0.5393 - dice_coef: 0.6987 - val_loss: 0.2053 - val_acc: 0.9913 - val_IOU: 0.6596 - val_dice_coef: 0.7947
# Learning rate:  0.0005
# Epoch 102/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2961 - acc: 0.9835 - IOU: 0.5461 - dice_coef: 0.7039Epoch 1/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.3094 - acc: 0.9817 - IOU: 0.5312 - dice_coef: 0.6906 - val_loss: 0.2134 - val_acc: 0.9910 - val_IOU: 0.6497 - val_dice_coef: 0.7866
# Learning rate:  0.0005
# Epoch 103/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3128 - acc: 0.9843 - IOU: 0.5256 - dice_coef: 0.6872Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3143 - acc: 0.9844 - IOU: 0.5242 - dice_coef: 0.6862 - val_loss: 0.2247 - val_acc: 0.9907 - val_IOU: 0.6337 - val_dice_coef: 0.7753
# Learning rate:  0.0005
# Epoch 104/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2897 - acc: 0.9835 - IOU: 0.5543 - dice_coef: 0.7103Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3010 - acc: 0.9828 - IOU: 0.5417 - dice_coef: 0.6995 - val_loss: 0.2096 - val_acc: 0.9913 - val_IOU: 0.6549 - val_dice_coef: 0.7904
# Learning rate:  0.0005
# Epoch 105/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3062 - acc: 0.9840 - IOU: 0.5339 - dice_coef: 0.6938Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.2985 - acc: 0.9841 - IOU: 0.5433 - dice_coef: 0.7016 - val_loss: 0.2071 - val_acc: 0.9914 - val_IOU: 0.6578 - val_dice_coef: 0.7929
# Learning rate:  0.0005
# Epoch 106/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3345 - acc: 0.9802 - IOU: 0.5023 - dice_coef: 0.6655Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3268 - acc: 0.9808 - IOU: 0.5117 - dice_coef: 0.6738 - val_loss: 0.1984 - val_acc: 0.9918 - val_IOU: 0.6702 - val_dice_coef: 0.8016
# Learning rate:  0.0005
# Epoch 107/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3104 - acc: 0.9844 - IOU: 0.5288 - dice_coef: 0.6896Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3023 - acc: 0.9850 - IOU: 0.5388 - dice_coef: 0.6979 - val_loss: 0.2113 - val_acc: 0.9915 - val_IOU: 0.6523 - val_dice_coef: 0.7887
# Learning rate:  0.0005
# Epoch 108/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3283 - acc: 0.9817 - IOU: 0.5092 - dice_coef: 0.6717Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3289 - acc: 0.9819 - IOU: 0.5089 - dice_coef: 0.6717 - val_loss: 0.2093 - val_acc: 0.9908 - val_IOU: 0.6544 - val_dice_coef: 0.7907
# Learning rate:  0.0005
# Epoch 109/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3136 - acc: 0.9829 - IOU: 0.5260 - dice_coef: 0.6864Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3180 - acc: 0.9829 - IOU: 0.5207 - dice_coef: 0.6820 - val_loss: 0.2122 - val_acc: 0.9908 - val_IOU: 0.6506 - val_dice_coef: 0.7878
# Learning rate:  0.0005
# Epoch 110/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3041 - acc: 0.9828 - IOU: 0.5366 - dice_coef: 0.6959Epoch 1/200
# 8/8 [==============================] - 1s 160ms/step - loss: 0.3029 - acc: 0.9831 - IOU: 0.5378 - dice_coef: 0.6971 - val_loss: 0.2161 - val_acc: 0.9904 - val_IOU: 0.6458 - val_dice_coef: 0.7839
# Learning rate:  0.0005
# Epoch 111/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3128 - acc: 0.9826 - IOU: 0.5262 - dice_coef: 0.6872Epoch 1/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3108 - acc: 0.9834 - IOU: 0.5295 - dice_coef: 0.6901 - val_loss: 0.2188 - val_acc: 0.9906 - val_IOU: 0.6422 - val_dice_coef: 0.7812
# Learning rate:  0.0005
# Epoch 112/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3166 - acc: 0.9842 - IOU: 0.5218 - dice_coef: 0.6834Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3324 - acc: 0.9824 - IOU: 0.5049 - dice_coef: 0.6676 - val_loss: 0.2165 - val_acc: 0.9908 - val_IOU: 0.6465 - val_dice_coef: 0.7835
# Learning rate:  0.0005
# Epoch 113/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2807 - acc: 0.9865 - IOU: 0.5633 - dice_coef: 0.7193Epoch 1/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.2771 - acc: 0.9861 - IOU: 0.5679 - dice_coef: 0.7230 - val_loss: 0.2287 - val_acc: 0.9900 - val_IOU: 0.6288 - val_dice_coef: 0.7713
# Learning rate:  0.0005
# Epoch 114/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3367 - acc: 0.9828 - IOU: 0.4996 - dice_coef: 0.6633Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3314 - acc: 0.9829 - IOU: 0.5057 - dice_coef: 0.6690 - val_loss: 0.2046 - val_acc: 0.9914 - val_IOU: 0.6609 - val_dice_coef: 0.7954
# Learning rate:  0.0005
# Epoch 115/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3137 - acc: 0.9827 - IOU: 0.5256 - dice_coef: 0.6863Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3190 - acc: 0.9825 - IOU: 0.5194 - dice_coef: 0.6810 - val_loss: 0.2153 - val_acc: 0.9910 - val_IOU: 0.6456 - val_dice_coef: 0.7847
# Learning rate:  0.0005
# Epoch 116/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2953 - acc: 0.9839 - IOU: 0.5472 - dice_coef: 0.7047Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2997 - acc: 0.9824 - IOU: 0.5420 - dice_coef: 0.7007 - val_loss: 0.3099 - val_acc: 0.9841 - val_IOU: 0.5282 - val_dice_coef: 0.6901
# Learning rate:  0.0005
# Epoch 117/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3158 - acc: 0.9850 - IOU: 0.5226 - dice_coef: 0.6842Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3099 - acc: 0.9849 - IOU: 0.5300 - dice_coef: 0.6905 - val_loss: 0.2386 - val_acc: 0.9901 - val_IOU: 0.6156 - val_dice_coef: 0.7614
# Learning rate:  0.0005
# Epoch 118/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3040 - acc: 0.9835 - IOU: 0.5365 - dice_coef: 0.6960Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3065 - acc: 0.9836 - IOU: 0.5340 - dice_coef: 0.6939 - val_loss: 0.2199 - val_acc: 0.9902 - val_IOU: 0.6403 - val_dice_coef: 0.7801
# Learning rate:  0.0005
# Epoch 119/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3118 - acc: 0.9821 - IOU: 0.5281 - dice_coef: 0.6882Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3122 - acc: 0.9826 - IOU: 0.5272 - dice_coef: 0.6878 - val_loss: 0.2456 - val_acc: 0.9904 - val_IOU: 0.6058 - val_dice_coef: 0.7544
# Learning rate:  0.0005
# Epoch 120/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3113 - acc: 0.9837 - IOU: 0.5270 - dice_coef: 0.6887Epoch 1/200
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3227 - acc: 0.9818 - IOU: 0.5153 - dice_coef: 0.6782 - val_loss: 0.2103 - val_acc: 0.9914 - val_IOU: 0.6536 - val_dice_coef: 0.7897
# Learning rate:  0.0005
# Epoch 121/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2890 - acc: 0.9845 - IOU: 0.5539 - dice_coef: 0.7110Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2916 - acc: 0.9845 - IOU: 0.5511 - dice_coef: 0.7088 - val_loss: 0.2247 - val_acc: 0.9900 - val_IOU: 0.6333 - val_dice_coef: 0.7753
# Learning rate:  0.0005
# Epoch 122/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2987 - acc: 0.9826 - IOU: 0.5427 - dice_coef: 0.7013Epoch 1/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.3023 - acc: 0.9829 - IOU: 0.5383 - dice_coef: 0.6977 - val_loss: 0.2139 - val_acc: 0.9912 - val_IOU: 0.6489 - val_dice_coef: 0.7861
# Learning rate:  0.0005
# Epoch 123/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3019 - acc: 0.9851 - IOU: 0.5395 - dice_coef: 0.6981Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3177 - acc: 0.9829 - IOU: 0.5226 - dice_coef: 0.6827 - val_loss: 0.2125 - val_acc: 0.9906 - val_IOU: 0.6500 - val_dice_coef: 0.7875
# Learning rate:  0.0005
# Epoch 124/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3233 - acc: 0.9830 - IOU: 0.5134 - dice_coef: 0.6767Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3271 - acc: 0.9828 - IOU: 0.5087 - dice_coef: 0.6726 - val_loss: 0.2206 - val_acc: 0.9902 - val_IOU: 0.6392 - val_dice_coef: 0.7794
# Learning rate:  0.0005
# Epoch 125/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3242 - acc: 0.9831 - IOU: 0.5142 - dice_coef: 0.6758Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3359 - acc: 0.9817 - IOU: 0.5018 - dice_coef: 0.6646 - val_loss: 0.2185 - val_acc: 0.9908 - val_IOU: 0.6420 - val_dice_coef: 0.7815
# Learning rate:  0.0005
# Epoch 126/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2847 - acc: 0.9859 - IOU: 0.5585 - dice_coef: 0.7153Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2889 - acc: 0.9858 - IOU: 0.5537 - dice_coef: 0.7114 - val_loss: 0.2345 - val_acc: 0.9899 - val_IOU: 0.6213 - val_dice_coef: 0.7655
# Learning rate:  0.0005
# Epoch 127/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3188 - acc: 0.9825 - IOU: 0.5215 - dice_coef: 0.6812Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3131 - acc: 0.9828 - IOU: 0.5282 - dice_coef: 0.6873 - val_loss: 0.2220 - val_acc: 0.9904 - val_IOU: 0.6371 - val_dice_coef: 0.7780
# Learning rate:  0.0005
# Epoch 128/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3031 - acc: 0.9850 - IOU: 0.5366 - dice_coef: 0.6969Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3099 - acc: 0.9849 - IOU: 0.5291 - dice_coef: 0.6906 - val_loss: 0.2139 - val_acc: 0.9908 - val_IOU: 0.6491 - val_dice_coef: 0.7861
# Learning rate:  0.0005
# Epoch 129/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3514 - acc: 0.9793 - IOU: 0.4845 - dice_coef: 0.6486Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3419 - acc: 0.9807 - IOU: 0.4956 - dice_coef: 0.6586 - val_loss: 0.2054 - val_acc: 0.9915 - val_IOU: 0.6600 - val_dice_coef: 0.7946
# Learning rate:  0.0005
# Epoch 130/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2801 - acc: 0.9854 - IOU: 0.5649 - dice_coef: 0.7199Epoch 1/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.2824 - acc: 0.9854 - IOU: 0.5620 - dice_coef: 0.7176 - val_loss: 0.1983 - val_acc: 0.9919 - val_IOU: 0.6702 - val_dice_coef: 0.8017
# Learning rate:  0.0005
# Epoch 131/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3445 - acc: 0.9804 - IOU: 0.4899 - dice_coef: 0.6555Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3424 - acc: 0.9811 - IOU: 0.4924 - dice_coef: 0.6580 - val_loss: 0.2032 - val_acc: 0.9914 - val_IOU: 0.6630 - val_dice_coef: 0.7968
# Learning rate:  0.0005
# Epoch 132/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2742 - acc: 0.9858 - IOU: 0.5707 - dice_coef: 0.7258Epoch 1/200
# 8/8 [==============================] - 1s 156ms/step - loss: 0.2748 - acc: 0.9858 - IOU: 0.5700 - dice_coef: 0.7252 - val_loss: 0.2125 - val_acc: 0.9912 - val_IOU: 0.6504 - val_dice_coef: 0.7875
# Learning rate:  0.0005
# Epoch 133/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3234 - acc: 0.9834 - IOU: 0.5135 - dice_coef: 0.6766Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3157 - acc: 0.9838 - IOU: 0.5225 - dice_coef: 0.6843 - val_loss: 0.2167 - val_acc: 0.9913 - val_IOU: 0.6457 - val_dice_coef: 0.7833
# Learning rate:  0.0005
# Epoch 134/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3135 - acc: 0.9835 - IOU: 0.5250 - dice_coef: 0.6865Epoch 1/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.3087 - acc: 0.9838 - IOU: 0.5310 - dice_coef: 0.6917 - val_loss: 0.2402 - val_acc: 0.9899 - val_IOU: 0.6130 - val_dice_coef: 0.7598
# Learning rate:  0.0005
# Epoch 135/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3135 - acc: 0.9825 - IOU: 0.5251 - dice_coef: 0.6865Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3050 - acc: 0.9829 - IOU: 0.5363 - dice_coef: 0.6956 - val_loss: 0.2288 - val_acc: 0.9908 - val_IOU: 0.6291 - val_dice_coef: 0.7712
# Learning rate:  0.0005
# Epoch 136/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3118 - acc: 0.9826 - IOU: 0.5269 - dice_coef: 0.6882Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3137 - acc: 0.9830 - IOU: 0.5250 - dice_coef: 0.6867 - val_loss: 0.2138 - val_acc: 0.9915 - val_IOU: 0.6483 - val_dice_coef: 0.7862
# Learning rate:  0.0005
# Epoch 137/200
# ...
# Learning rate:  0.0005
# Epoch 156/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3183 - acc: 0.9810 - IOU: 0.5198 - dice_coef: 0.6817Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3113 - acc: 0.9818 - IOU: 0.5285 - dice_coef: 0.6891 - val_loss: 0.2389 - val_acc: 0.9894 - val_IOU: 0.6168 - val_dice_coef: 0.7611
# Learning rate:  0.0005
# Epoch 157/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3233 - acc: 0.9827 - IOU: 0.5135 - dice_coef: 0.6767Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3278 - acc: 0.9810 - IOU: 0.5084 - dice_coef: 0.6722 - val_loss: 0.2281 - val_acc: 0.9900 - val_IOU: 0.6295 - val_dice_coef: 0.7719
# Learning rate:  0.0005
# Epoch 158/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2991 - acc: 0.9857 - IOU: 0.5417 - dice_coef: 0.7009Epoch 1/200
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3012 - acc: 0.9857 - IOU: 0.5397 - dice_coef: 0.6994 - val_loss: 0.2357 - val_acc: 0.9903 - val_IOU: 0.6192 - val_dice_coef: 0.7643
# Learning rate:  0.0005
# Epoch 159/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3266 - acc: 0.9814 - IOU: 0.5137 - dice_coef: 0.6734Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3203 - acc: 0.9825 - IOU: 0.5207 - dice_coef: 0.6800 - val_loss: 0.2215 - val_acc: 0.9902 - val_IOU: 0.6383 - val_dice_coef: 0.7785
# Learning rate:  0.0005
# Epoch 160/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3036 - acc: 0.9842 - IOU: 0.5370 - dice_coef: 0.6964Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.2958 - acc: 0.9847 - IOU: 0.5464 - dice_coef: 0.7042 - val_loss: 0.2160 - val_acc: 0.9908 - val_IOU: 0.6455 - val_dice_coef: 0.7840
# Learning rate:  0.0005
# Epoch 161/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2930 - acc: 0.9849 - IOU: 0.5496 - dice_coef: 0.7070Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.2956 - acc: 0.9850 - IOU: 0.5468 - dice_coef: 0.7048 - val_loss: 0.2190 - val_acc: 0.9900 - val_IOU: 0.6408 - val_dice_coef: 0.7810
# Learning rate:  0.0005
# Epoch 162/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3032 - acc: 0.9830 - IOU: 0.5381 - dice_coef: 0.6968Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2964 - acc: 0.9834 - IOU: 0.5468 - dice_coef: 0.7041 - val_loss: 0.2146 - val_acc: 0.9907 - val_IOU: 0.6470 - val_dice_coef: 0.7854
# Learning rate:  0.0005
# Epoch 163/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2945 - acc: 0.9846 - IOU: 0.5468 - dice_coef: 0.7055Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2901 - acc: 0.9849 - IOU: 0.5523 - dice_coef: 0.7102 - val_loss: 0.2241 - val_acc: 0.9904 - val_IOU: 0.6345 - val_dice_coef: 0.7759
# Learning rate:  0.0005
# Epoch 164/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3191 - acc: 0.9841 - IOU: 0.5187 - dice_coef: 0.6809Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3197 - acc: 0.9844 - IOU: 0.5183 - dice_coef: 0.6807 - val_loss: 0.2041 - val_acc: 0.9914 - val_IOU: 0.6615 - val_dice_coef: 0.7959
# Learning rate:  0.0005
# Epoch 165/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3196 - acc: 0.9816 - IOU: 0.5190 - dice_coef: 0.6804Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3284 - acc: 0.9810 - IOU: 0.5091 - dice_coef: 0.6716 - val_loss: 0.2349 - val_acc: 0.9892 - val_IOU: 0.6197 - val_dice_coef: 0.7651
# Learning rate:  0.0005
# Epoch 166/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2939 - acc: 0.9850 - IOU: 0.5481 - dice_coef: 0.7061Epoch 1/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3031 - acc: 0.9845 - IOU: 0.5380 - dice_coef: 0.6975 - val_loss: 0.2076 - val_acc: 0.9914 - val_IOU: 0.6573 - val_dice_coef: 0.7924
# Learning rate:  0.0005
# Epoch 167/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3055 - acc: 0.9824 - IOU: 0.5343 - dice_coef: 0.6945Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3000 - acc: 0.9829 - IOU: 0.5407 - dice_coef: 0.7000 - val_loss: 0.3152 - val_acc: 0.9885 - val_IOU: 0.5215 - val_dice_coef: 0.6848
# Learning rate:  0.0005
# Epoch 168/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3025 - acc: 0.9837 - IOU: 0.5371 - dice_coef: 0.6975Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3071 - acc: 0.9832 - IOU: 0.5321 - dice_coef: 0.6932 - val_loss: 0.2468 - val_acc: 0.9892 - val_IOU: 0.6046 - val_dice_coef: 0.7532
# Learning rate:  0.0005
# Epoch 169/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3249 - acc: 0.9839 - IOU: 0.5124 - dice_coef: 0.6751Epoch 1/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.3290 - acc: 0.9840 - IOU: 0.5081 - dice_coef: 0.6715 - val_loss: 0.2520 - val_acc: 0.9892 - val_IOU: 0.5979 - val_dice_coef: 0.7480
# Learning rate:  0.0005
# Epoch 170/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3094 - acc: 0.9833 - IOU: 0.5326 - dice_coef: 0.6906Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3118 - acc: 0.9835 - IOU: 0.5299 - dice_coef: 0.6887 - val_loss: 0.2448 - val_acc: 0.9890 - val_IOU: 0.6079 - val_dice_coef: 0.7552
# Learning rate:  0.0005
# Epoch 171/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3109 - acc: 0.9822 - IOU: 0.5291 - dice_coef: 0.6891Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3099 - acc: 0.9826 - IOU: 0.5304 - dice_coef: 0.6904 - val_loss: 0.2231 - val_acc: 0.9903 - val_IOU: 0.6362 - val_dice_coef: 0.7769
# Learning rate:  0.0005
# Epoch 172/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2979 - acc: 0.9844 - IOU: 0.5453 - dice_coef: 0.7021Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2969 - acc: 0.9847 - IOU: 0.5467 - dice_coef: 0.7035 - val_loss: 0.2201 - val_acc: 0.9905 - val_IOU: 0.6390 - val_dice_coef: 0.7799
# Learning rate:  0.0005
# Epoch 173/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3092 - acc: 0.9842 - IOU: 0.5300 - dice_coef: 0.6908Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3085 - acc: 0.9844 - IOU: 0.5311 - dice_coef: 0.6919 - val_loss: 0.2437 - val_acc: 0.9890 - val_IOU: 0.6087 - val_dice_coef: 0.7563
# Learning rate:  0.0005
# Epoch 174/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3215 - acc: 0.9810 - IOU: 0.5176 - dice_coef: 0.6785Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3130 - acc: 0.9816 - IOU: 0.5274 - dice_coef: 0.6870 - val_loss: 0.2392 - val_acc: 0.9890 - val_IOU: 0.6144 - val_dice_coef: 0.7608
# Learning rate:  0.0005
# Epoch 175/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3047 - acc: 0.9833 - IOU: 0.5352 - dice_coef: 0.6953Epoch 1/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.3004 - acc: 0.9838 - IOU: 0.5405 - dice_coef: 0.6999 - val_loss: 0.2125 - val_acc: 0.9910 - val_IOU: 0.6508 - val_dice_coef: 0.7875
# Learning rate:  0.0005
# Epoch 176/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2977 - acc: 0.9845 - IOU: 0.5439 - dice_coef: 0.7023Epoch 1/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.2928 - acc: 0.9847 - IOU: 0.5510 - dice_coef: 0.7082 - val_loss: 0.2124 - val_acc: 0.9908 - val_IOU: 0.6498 - val_dice_coef: 0.7876
# Learning rate:  0.0005
# Epoch 177/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3370 - acc: 0.9795 - IOU: 0.4998 - dice_coef: 0.6630Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3413 - acc: 0.9795 - IOU: 0.4946 - dice_coef: 0.6587 - val_loss: 0.2134 - val_acc: 0.9908 - val_IOU: 0.6491 - val_dice_coef: 0.7866
# Learning rate:  0.0005
# Epoch 178/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2976 - acc: 0.9848 - IOU: 0.5427 - dice_coef: 0.7024Epoch 1/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.2917 - acc: 0.9851 - IOU: 0.5504 - dice_coef: 0.7088 - val_loss: 0.2118 - val_acc: 0.9912 - val_IOU: 0.6504 - val_dice_coef: 0.7882
# Learning rate:  0.0005
# Epoch 179/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3168 - acc: 0.9835 - IOU: 0.5202 - dice_coef: 0.6832Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3109 - acc: 0.9841 - IOU: 0.5274 - dice_coef: 0.6891 - val_loss: 0.2227 - val_acc: 0.9900 - val_IOU: 0.6363 - val_dice_coef: 0.7773
# Learning rate:  0.0005
# Epoch 180/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2755 - acc: 0.9846 - IOU: 0.5703 - dice_coef: 0.7245Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2883 - acc: 0.9840 - IOU: 0.5558 - dice_coef: 0.7119 - val_loss: 0.2050 - val_acc: 0.9913 - val_IOU: 0.6608 - val_dice_coef: 0.7950
# Learning rate:  0.0005
# Epoch 181/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2914 - acc: 0.9855 - IOU: 0.5510 - dice_coef: 0.7086Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3024 - acc: 0.9837 - IOU: 0.5390 - dice_coef: 0.6981 - val_loss: 0.2190 - val_acc: 0.9901 - val_IOU: 0.6413 - val_dice_coef: 0.7810
# Learning rate:  0.0005
# Epoch 182/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2924 - acc: 0.9836 - IOU: 0.5496 - dice_coef: 0.7076Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2926 - acc: 0.9838 - IOU: 0.5492 - dice_coef: 0.7074 - val_loss: 0.2569 - val_acc: 0.9877 - val_IOU: 0.5927 - val_dice_coef: 0.7431
# Learning rate:  0.0005
# Epoch 183/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3560 - acc: 0.9817 - IOU: 0.4777 - dice_coef: 0.6440Epoch 1/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.3543 - acc: 0.9821 - IOU: 0.4793 - dice_coef: 0.6457 - val_loss: 0.2539 - val_acc: 0.9883 - val_IOU: 0.5959 - val_dice_coef: 0.7461
# Learning rate:  0.0005
# Epoch 184/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2979 - acc: 0.9845 - IOU: 0.5446 - dice_coef: 0.7021Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3022 - acc: 0.9845 - IOU: 0.5398 - dice_coef: 0.6983 - val_loss: 0.2103 - val_acc: 0.9908 - val_IOU: 0.6532 - val_dice_coef: 0.7897
# Learning rate:  0.0005
# Epoch 185/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2991 - acc: 0.9834 - IOU: 0.5429 - dice_coef: 0.7009Epoch 1/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.2982 - acc: 0.9842 - IOU: 0.5444 - dice_coef: 0.7024 - val_loss: 0.2118 - val_acc: 0.9908 - val_IOU: 0.6512 - val_dice_coef: 0.7882
# Learning rate:  0.0005
# Epoch 186/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3248 - acc: 0.9820 - IOU: 0.5138 - dice_coef: 0.6752Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3350 - acc: 0.9804 - IOU: 0.5023 - dice_coef: 0.6650 - val_loss: 0.2359 - val_acc: 0.9893 - val_IOU: 0.6186 - val_dice_coef: 0.7641
# Learning rate:  0.0005
# Epoch 187/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2855 - acc: 0.9858 - IOU: 0.5574 - dice_coef: 0.7145Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2858 - acc: 0.9862 - IOU: 0.5571 - dice_coef: 0.7144 - val_loss: 0.2076 - val_acc: 0.9911 - val_IOU: 0.6571 - val_dice_coef: 0.7924
# Learning rate:  0.0005
# Epoch 188/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3192 - acc: 0.9820 - IOU: 0.5188 - dice_coef: 0.6808Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3261 - acc: 0.9819 - IOU: 0.5117 - dice_coef: 0.6746 - val_loss: 0.2070 - val_acc: 0.9914 - val_IOU: 0.6574 - val_dice_coef: 0.7930
# Learning rate:  0.0005
# Epoch 189/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2679 - acc: 0.9857 - IOU: 0.5787 - dice_coef: 0.7321Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2782 - acc: 0.9854 - IOU: 0.5668 - dice_coef: 0.7219 - val_loss: 0.2065 - val_acc: 0.9913 - val_IOU: 0.6584 - val_dice_coef: 0.7935
# Learning rate:  0.0005
# Epoch 190/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2945 - acc: 0.9835 - IOU: 0.5473 - dice_coef: 0.7055Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2932 - acc: 0.9836 - IOU: 0.5487 - dice_coef: 0.7069 - val_loss: 0.2085 - val_acc: 0.9915 - val_IOU: 0.6556 - val_dice_coef: 0.7915
# Learning rate:  0.0005
# Epoch 191/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2911 - acc: 0.9846 - IOU: 0.5506 - dice_coef: 0.7089Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2908 - acc: 0.9846 - IOU: 0.5509 - dice_coef: 0.7092 - val_loss: 0.2183 - val_acc: 0.9912 - val_IOU: 0.6415 - val_dice_coef: 0.7817
# Learning rate:  0.0005
# Epoch 192/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2962 - acc: 0.9858 - IOU: 0.5456 - dice_coef: 0.7038Epoch 1/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.2941 - acc: 0.9858 - IOU: 0.5480 - dice_coef: 0.7060 - val_loss: 0.2059 - val_acc: 0.9914 - val_IOU: 0.6595 - val_dice_coef: 0.7941
# Learning rate:  0.0005
# Epoch 193/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2800 - acc: 0.9843 - IOU: 0.5644 - dice_coef: 0.7200Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2756 - acc: 0.9846 - IOU: 0.5702 - dice_coef: 0.7247 - val_loss: 0.2103 - val_acc: 0.9911 - val_IOU: 0.6535 - val_dice_coef: 0.7897
# Learning rate:  0.0005
# Epoch 194/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3069 - acc: 0.9837 - IOU: 0.5333 - dice_coef: 0.6931Epoch 1/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.3059 - acc: 0.9823 - IOU: 0.5341 - dice_coef: 0.6941 - val_loss: 0.2164 - val_acc: 0.9905 - val_IOU: 0.6452 - val_dice_coef: 0.7836
# Learning rate:  0.0005
# Epoch 195/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2823 - acc: 0.9859 - IOU: 0.5609 - dice_coef: 0.7177Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2824 - acc: 0.9848 - IOU: 0.5610 - dice_coef: 0.7179 - val_loss: 0.2021 - val_acc: 0.9914 - val_IOU: 0.6658 - val_dice_coef: 0.7979
# Learning rate:  0.0005
# Epoch 196/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2961 - acc: 0.9855 - IOU: 0.5443 - dice_coef: 0.7039Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2935 - acc: 0.9858 - IOU: 0.5479 - dice_coef: 0.7069 - val_loss: 0.2169 - val_acc: 0.9907 - val_IOU: 0.6452 - val_dice_coef: 0.7831
# Learning rate:  0.0005
# Epoch 197/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2961 - acc: 0.9832 - IOU: 0.5454 - dice_coef: 0.7039Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2961 - acc: 0.9835 - IOU: 0.5453 - dice_coef: 0.7040 - val_loss: 0.2483 - val_acc: 0.9885 - val_IOU: 0.6033 - val_dice_coef: 0.7517
# Learning rate:  0.0005
# Epoch 198/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2737 - acc: 0.9856 - IOU: 0.5720 - dice_coef: 0.7263Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2865 - acc: 0.9849 - IOU: 0.5575 - dice_coef: 0.7138 - val_loss: 0.2211 - val_acc: 0.9903 - val_IOU: 0.6383 - val_dice_coef: 0.7789
# Learning rate:  0.0005
# Epoch 199/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3386 - acc: 0.9796 - IOU: 0.4981 - dice_coef: 0.6614Epoch 1/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3250 - acc: 0.9808 - IOU: 0.5149 - dice_coef: 0.6755 - val_loss: 0.2188 - val_acc: 0.9907 - val_IOU: 0.6417 - val_dice_coef: 0.7812
# Learning rate:  0.0005
# Epoch 200/200
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2707 - acc: 0.9853 - IOU: 0.5753 - dice_coef: 0.7293Epoch 1/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2835 - acc: 0.9848 - IOU: 0.5605 - dice_coef: 0.7165 - val_loss: 0.2218 - val_acc: 0.9903 - val_IOU: 0.6379 - val_dice_coef: 0.7782

# %%
train_loss = history.history['loss']
valid_loss = history.history['val_loss']

train_acc = history.history['acc']
valid_acc = history.history['val_acc']

# %%
fig, axes = plt.subplots(1, 2, figsize=(13,4))
axes = axes.flatten()

axes[0].plot(train_acc, label='training')
axes[0].plot(valid_acc, label='validation')
axes[0].set_title('Accuracy Curve')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('accuracy')
axes[0].legend()


axes[1].plot(train_loss, label='training')
axes[1].plot(valid_loss, label='validation')
axes[1].set_title('Loss Curve')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('loss')
axes[1].legend()

plt.show()

# %%
train_dice = history.history['dice_coef']
valid_dice = history.history['val_dice_coef']


train_IOU = history.history['IOU']
valid_IOU = history.history['val_IOU']

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,7))
axes = axes.flatten()

axes[0].plot(train_IOU, label='training')
axes[0].plot(valid_IOU, label='validation')
axes[0].set_title('IOU Curve [Adam lr : 0.0001]')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('IOU')
axes[0].legend()


axes[1].plot(train_dice, label='training')
axes[1].plot(valid_dice, label='validation')
axes[1].set_title('Dice coefficient Curve [Adam lr : 0.0001]')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('dice_coef')
axes[1].legend()

plt.show()

# %%
# Model save
model.save(model_path)

# %% [markdown]
# ## Testing

# %%
model.load_weights(model_path)

print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
num_val_files = len(val_image_files)
test_generator = Generator(val_image_files, val_mask_files, num_val_files, img_dim)

for x_test, y_test in test_generator:
  break

y_pred = model.predict(x_test)

yy_true = (y_test>0.5).flatten()
yy_pred = (y_pred>0.5).flatten()

# %%
report = classification_report(yy_true, yy_pred, output_dict=True)

Accuracy = accuracy_score(yy_true, yy_pred)

AP = average_precision_score(y_test.flatten(), y_pred.flatten())

Precision = report['True']['precision']
Recall = report['True']['recall']
F1_score = report['True']['f1-score']

Sensitivity = Recall
Specificity = report['False']['recall']

AUC = roc_auc_score(y_test.flatten(), y_pred.flatten())

IOU = (Precision*Recall)/(Precision+Recall-Precision*Recall)

print("Accuracy: {0:.4f}\n".format(Accuracy))
print("AP: {0:.4f}\n".format(AP))
print("Precision: {0:.4f}\n".format(Precision))
print("Recall: {0:.4f}\n".format(Recall))
print("F1-Score: {0:.4f}\n".format(F1_score))
print("Sensitivity: {0:.4f}\n".format(Sensitivity))
print("Specificity: {0:.4f}\n".format(Specificity))
print("AUC: {0:.4f}\n".format(AUC))
print("IOU: {0:.4f}\n".format(IOU))
print('-'*50,'\n')
print(classification_report(yy_true, yy_pred))
# Out:
# Accuracy: 0.9903
#
# AP: 0.7481
#
# Precision: 0.7255
#
# Recall: 0.8409
#
# F1-Score: 0.7789
#
# Sensitivity: 0.8409
#
# Specificity: 0.9934
#
# AUC: 0.9454
#
# IOU: 0.6379
#
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      1.00    642083
#         True       0.73      0.84      0.78     13277
#
#     accuracy                           0.99    655360
#    macro avg       0.86      0.92      0.89    655360
# weighted avg       0.99      0.99      0.99    655360

# %%
num_test_files = len(test_image_paths)
test_generator1 = Generator(test_image_paths,test_mask_paths,num_test_files, img_dim)

for x_test, y_test in test_generator1:
  break

y_pred = model.predict(x_test)

yy_true = (y_test>0.5).flatten()
yy_pred = (y_pred>0.5).flatten()

# %%
report = classification_report(yy_true, yy_pred, output_dict=True)

Accuracy = accuracy_score(yy_true, yy_pred)

AP = average_precision_score(y_test.flatten(), y_pred.flatten())

Precision = report['True']['precision']
Recall = report['True']['recall']
F1_score = report['True']['f1-score']

Sensitivity = Recall
Specificity = report['False']['recall']

AUC = roc_auc_score(y_test.flatten(), y_pred.flatten())

IOU = (Precision*Recall)/(Precision+Recall-Precision*Recall)

print("Accuracy: {0:.4f}\n".format(Accuracy))
print("AP: {0:.4f}\n".format(AP))
print("Precision: {0:.4f}\n".format(Precision))
print("Recall: {0:.4f}\n".format(Recall))
print("F1-Score: {0:.4f}\n".format(F1_score))
print("Sensitivity: {0:.4f}\n".format(Sensitivity))
print("Specificity: {0:.4f}\n".format(Specificity))
print("AUC: {0:.4f}\n".format(AUC))
print("IOU: {0:.4f}\n".format(IOU))
print('-'*50,'\n')
print(classification_report(yy_true, yy_pred))
# Out:
# Accuracy: 0.9688
#
# AP: 0.4822
#
# Precision: 0.7835
#
# Recall: 0.4488
#
# F1-Score: 0.5707
#
# Sensitivity: 0.4488
#
# Specificity: 0.9940
#
# AUC: 0.7619
#
# IOU: 0.3993
#
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#        False       0.97      0.99      0.98   1500175
#         True       0.78      0.45      0.57     72689
#
#     accuracy                           0.97   1572864
#    macro avg       0.88      0.72      0.78   1572864
# weighted avg       0.97      0.97      0.96   1572864

# %%
def plot_image(i, predictions_array, img):
  img = img[i]

  plt.grid(False)
  plt.xticks([])
  plt.yticks([])   
  indices = np.where(predictions_array!=[0])

  plt.imshow(img)#, cmap=plt.cm.binary)
  save_path = '/home/adip/crack_ws/src/datasets/Crack500/results/mask'
  cv2.imwrite(os.path.join(save_path, '{}.png'.format(i)), img)
